# %%
import pandas as pd

# %%
df= pd.read_csv('../data/Crimes_-_2001_to_Present_20260406.csv')

# %%
df.shape
# Out:
# (544114, 22)

# %%
df.head()
# Out:
#          ID Case Number                    Date                     Block  \
# 0  14151264    JK198186  03/28/2026 12:00:00 AM         026XX N EMMETT ST
# 1  14150705    JK197983  03/28/2026 12:00:00 AM           026XX E 78TH ST
# 2  14154257    JK202214  03/28/2026 12:00:00 AM  011XX S CENTRAL PARK AVE
# 3  14150115    JK197373  03/28/2026 12:00:00 AM           006XX E 40TH ST
# 4  14155860    JK204251  03/28/2026 12:00:00 AM           020XX E 72ND ST
#
#    IUCR         Primary Type  \
# 0  0760             BURGLARY
# 1  1320      CRIMINAL DAMAGE
# 2  0498              BATTERY
# 3  0920  MOTOR VEHICLE THEFT
# 4  0460              BATTERY
#
#                                          Description Location Description  \
# 0                        BURGLARY FROM MOTOR VEHICLE               STREET
# 1                                         TO VEHICLE               STREET
# 2  AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SE...            APARTMENT
# 3                               ATTEMPT - AUTOMOBILE               STREET
# 4                                             SIMPLE               STREET
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0   False     False  ...  35.0            22.0        06     1154412.0
# 1   False     False  ...   7.0            43.0        14     1194996.0
# 2   False      True  ...  24.0            29.0       04B     1152552.0
# 3   False     False  ...   4.0            38.0        07     1181163.0
# 4   False     False  ...   5.0            43.0       08B           NaN
#
#   Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0    1917923.0  2026  04/04/2026 03:58:05 PM  41.930605 -87.707987
# 1    1853754.0  2026  04/04/2026 03:58:05 PM  41.753614 -87.560973
# 2    1894695.0  2026  04/04/2026 03:58:05 PM  41.866903 -87.715437
# 3    1878357.0  2026  04/04/2026 03:58:05 PM  41.821457 -87.610908
# 4          NaN  2026  04/04/2026 03:58:05 PM        NaN        NaN
#
#                         Location
# 0  (41.930605381, -87.707987093)
# 1  (41.753614382, -87.560973062)
# 2  (41.866902523, -87.715436986)
# 3  (41.821456863, -87.610907852)
# 4                            NaN
#
# [5 rows x 22 columns]

# %%
df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
df=df.dropna(subset=['X Coordinate'])

# %%
df=df.dropna(subset=['Ward'])

# %%
df=df.dropna(subset=['Community Area'])

# %%
df=df.dropna(subset=['Location Description'])

# %%
df.shape
# Out:
# (538842, 22)

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='str')

# %%
df=df.head(500000)

# %%
df.shape
# Out:
# (500000, 22)

# %%
df.head()
# Out:
#          ID Case Number                    Date                     Block  \
# 0  14151264    JK198186  03/28/2026 12:00:00 AM         026XX N EMMETT ST
# 1  14150705    JK197983  03/28/2026 12:00:00 AM           026XX E 78TH ST
# 2  14154257    JK202214  03/28/2026 12:00:00 AM  011XX S CENTRAL PARK AVE
# 3  14150115    JK197373  03/28/2026 12:00:00 AM           006XX E 40TH ST
# 5  14149655    JK196703  03/28/2026 12:00:00 AM       048XX S DREXEL BLVD
#
#    IUCR         Primary Type  \
# 0  0760             BURGLARY
# 1  1320      CRIMINAL DAMAGE
# 2  0498              BATTERY
# 3  0920  MOTOR VEHICLE THEFT
# 5  0486              BATTERY
#
#                                          Description Location Description  \
# 0                        BURGLARY FROM MOTOR VEHICLE               STREET
# 1                                         TO VEHICLE               STREET
# 2  AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SE...            APARTMENT
# 3                               ATTEMPT - AUTOMOBILE               STREET
# 5                            DOMESTIC BATTERY SIMPLE            APARTMENT
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0   False     False  ...  35.0            22.0        06     1154412.0
# 1   False     False  ...   7.0            43.0        14     1194996.0
# 2   False      True  ...  24.0            29.0       04B     1152552.0
# 3   False     False  ...   4.0            38.0        07     1181163.0
# 5   False      True  ...   4.0            39.0       08B     1183004.0
#
#   Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 0    1917923.0  2026  04/04/2026 03:58:05 PM  41.930605 -87.707987
# 1    1853754.0  2026  04/04/2026 03:58:05 PM  41.753614 -87.560973
# 2    1894695.0  2026  04/04/2026 03:58:05 PM  41.866903 -87.715437
# 3    1878357.0  2026  04/04/2026 03:58:05 PM  41.821457 -87.610908
# 5    1873073.0  2026  04/04/2026 03:58:05 PM  41.806914 -87.604319
#
#                         Location
# 0  (41.930605381, -87.707987093)
# 1  (41.753614382, -87.560973062)
# 2  (41.866902523, -87.715436986)
# 3  (41.821456863, -87.610907852)
# 5  (41.806914497, -87.604318647)
#
# [5 rows x 22 columns]

# %%
df['IUCR'].value_counts()
# Out:
# IUCR
# 0486    39875
# 0820    34601
# 0460    31874
# 0810    31711
# 1320    30209
#         ...
# 2094        1
# 1715        1
# 1530        1
# 0272        1
# 2080        1
# Name: count, Length: 352, dtype: int64

# %%
cols = [
'ID','Date','Primary Type','Description',
'Location Description','Arrest','Domestic',
'District','Ward','Community Area',
'Latitude','Longitude'
]

df = df[cols]

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# /var/folders/33/6j7x5yjn4vs9rpp5_xx32x740000gn/T/ipykernel_1425/2394721818.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# -- Date column Feature engineering

# %%
df['hour'] = df['Date'].dt.hour
df['day'] = df['Date'].dt.day_name()
df['month'] = df['Date'].dt.month
df['year'] = df['Date'].dt.year
df['weekend'] = df['Date'].dt.dayofweek >= 5

# %%
df.shape
# Out:
# (500000, 17)

# %%
df.to_csv('data/cleaned_crime_records.csv', index=False)
